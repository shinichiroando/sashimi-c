# %% [markdown]
# # Subhalo Mass Stripping Perturbation Theory up to Second Order
#
# ## Introduction
#
# In modeling the mass loss of subhalos within a cosmological context, it is essential to accurately represent how subhalos lose mass due to tidal stripping. This note provides the mathematical derivation of the perturbative solution for subhalo mass stripping, accounting for small deviations in key parameters. By properly handling the perturbation expansion, we ensure accurate modeling of subhalo mass evolution.
#
# ---
#
# ## 1. Mass Evolution Equation
#
# The mass evolution of a subhalo $m(z)$ as a function of redshift $z$ is governed by the differential equation:
#
# $$
# \frac{dm}{dz} = \Phi(z) \cdot m(z) \left( \frac{m(z)}{M_{\text{vir}}(z)} \right)^{\zeta(z)}
# $$
#
# Where:
#
# - $\Phi(z) = \dfrac{A(z)}{t_{\text{dyn}}(z) H(z) (1 + z)}$
# - $A(z)$: Stripping efficiency function.
# - $t_{\text{dyn}}(z)$: Dynamical time at redshift $z$.
# - $M_{\text{vir}}(z)$: Virial mass of the host halo at redshift $z$.
# - $\zeta(z)$: Exponent characterizing the mass dependence of stripping.
# - $H(z)$: Hubble parameter at redshift $z$.
#
# ---
#
# ## 2. Zeroth-Order Solution
#
# Assuming $\zeta(z)$ is approximately zero (i.e., $\zeta(z) = \zeta_0 \approx 0$), the equation simplifies to:
#
# $$
# \frac{dm}{dz} = \Phi(z) \cdot m(z)
# $$
#
# This is a separable differential equation. Separating variables:
#
# $$
# \frac{dm}{m(z)} = \Phi(z) dz
# $$
#
# Integrating both sides from the accretion redshift $z_{\text{a}}$ (where $m = m_{\text{a}}$) to $z$:
#
# $$
# \int_{m_{\text{a}}}^{m_0(z)} \frac{1}{m} dm = \int_{z_{\text{a}}}^{z} \Phi(z') dz'
# $$
#
# This yields the zeroth-order solution:
#
# $$
# \ln m_0(z) - \ln m_{\text{a}} = \int_{z_{\text{a}}}^{z} \Phi(z') dz'
# $$
#
# $$
# \Rightarrow m_0(z) = m_{\text{a}} \cdot \exp\left( \int_{z_{\text{a}}}^{z} \Phi(z') dz' \right)
# $$
#
# This solution represents the exponential mass loss of subhalo mass due to the tidal stripping stripping assuming ($\zeta_0 \approx 0$).
#
# ---
#
# ## 3. First-Order Perturbation
#
# To account for the small but non-zero $\zeta(z)$, we introduce a perturbation expansion:
#
# - $\zeta(z) = \zeta_0 + \zeta_1(z)$, where $\zeta_0 \approx 0$.
# - Expand $m(z)$ as $m(z) = m_0(z) \cdot e^{\epsilon(z)}$, where $\epsilon(z)$ is a small first-order correction.
#
# ### 3.1. Derivation of $\epsilon(z)$
#
# Starting from the differential equation:
#
# $$
# \frac{dm}{dz} = \Phi(z) \cdot m(z) \left( \frac{m(z)}{M_{\text{vir}}(z)} \right)^{\zeta(z)}
# $$
#
# Substituting $m(z) = m_0(z) e^{\epsilon(z)}$ and $\zeta(z) = \zeta_1(z)$:
#
# $$
# \frac{d}{dz} \left[ m_0(z) e^{\epsilon(z)} \right] = \Phi(z) m_0(z) e^{\epsilon(z)} \exp\left[ \zeta_1(z) \ln\left( \frac{m_0(z) e^{\epsilon(z)}}{M_{\text{vir}}(z)} \right) \right]
# $$
#
# Simplifying:
#
# 1. **Left-Hand Side (LHS):**
#
# $$
# \frac{d}{dz} \left[ m_0(z) e^{\epsilon(z)} \right] = m_0'(z) e^{\epsilon(z)} + m_0(z) e^{\epsilon(z)} \epsilon'(z)
# $$
#
# 2. **Right-Hand Side (RHS):**
#
# $$
# \Phi(z) m_0(z) e^{\epsilon(z)} \left[ 1 + \zeta_1(z) \left( \ln\left( \frac{m_0(z)}{M_{\text{vir}}(z)} \right) + \epsilon(z) \right) \right]
# $$
#
#    - Used the approximation $\exp(\zeta_1(z) x) \approx 1 + \zeta_1(z) x$ since $\zeta_1(z)$ is small.
#
# 3. **Equate LHS and RHS:**
#
# $$
# m_0'(z) e^{\epsilon(z)} + m_0(z) e^{\epsilon(z)} \epsilon'(z) = \Phi(z) m_0(z) e^{\epsilon(z)} \left[ 1 + \zeta_1(z) \left( \ln\left( \frac{m_0(z)}{M_{\text{vir}}(z)} \right) + \epsilon(z) \right) \right]
# $$
#
# 4. **Cancel Common Factors:**
#
# Divide both sides by $e^{\epsilon(z)}$:
#
# $$
# m_0'(z) + m_0(z) \epsilon'(z) = \Phi(z) m_0(z) \left[ 1 + \zeta_1(z) \left( \ln\left( \frac{m_0(z)}{M_{\text{vir}}(z)} \right) + \epsilon(z) \right) \right]
# $$
#
# 5. **Use $m_0'(z) = \Phi(z) m_0(z)$:**
#
# From the zeroth-order solution:
#
# $$
# m_0'(z) = \Phi(z) m_0(z)
# $$
#
# 6. **Subtract $m_0'(z)$ from both sides:**
#
# $$
# m_0(z) \epsilon'(z) = \Phi(z) m_0(z) \left[ \zeta_1(z) \left( \ln\left( \frac{m_0(z)}{M_{\text{vir}}(z)} \right) + \epsilon(z) \right) \right]
# $$
#
# 7. **Divide by $m_0(z)$:**
#
# $$
# \epsilon'(z) = \Phi(z) \zeta_1(z) \left( \ln\left( \frac{m_0(z)}{M_{\text{vir}}(z)} \right) + \epsilon(z) \right)
# $$
#
# Since $\epsilon(z)$ is small (first-order), we can neglect the $\epsilon(z)$ term on the right-hand side (second-order effect):
#
# $$
# \epsilon'(z) = \Phi(z) \zeta_1(z) \ln\left( \frac{m_0(z)}{M_{\text{vir}}(z)} \right)
# $$
#
# **Integrate Both Sides:**
#
# $$
# \epsilon(z) = \int_{z_{\text{a}}}^{z} \Phi(z') \zeta_1(z') \ln\left( \frac{m_0(z')}{M_{\text{vir}}(z')} \right) dz'
# $$
#
# ### 3.2. Simplifying $\epsilon(z)$
#
# Using the expression for $m_0(z')$:
#
# $$
# \ln m_0(z') = \ln m_{\text{a}} + \int_{z_{\text{a}}}^{z'} \Phi(u) du
# $$
#
# Therefore,
#
# $$
# \ln\left( \frac{m_0(z')}{M_{\text{vir}}(z')} \right) = \ln m_{\text{a}} + \int_{z_{\text{a}}}^{z'} \Phi(u) du - \ln M_{\text{vir}}(z')
# $$
#
# Substitute back into $\epsilon(z)$:
#
# $$
# \epsilon(z) = \int_{z_{\text{a}}}^{z} \Phi(z') \zeta_1(z') \left[ \ln m_{\text{a}} + \int_{z_{\text{a}}}^{z'} \Phi(u) du - \ln M_{\text{vir}}(z') \right] dz'
# $$
#
# This expression can be split into three separate integrals:
#
# $$
# \epsilon(z) = \epsilon_1(z) + \epsilon_2(z) + \epsilon_3(z)
# $$
#
# Where:
#
# - $\epsilon_1(z) = \ln m_{\text{a}} \int_{z_{\text{a}}}^{z} \Phi(z') \zeta_1(z') dz'$
# - $\epsilon_2(z) = -\int_{z_{\text{a}}}^{z} \Phi(z') \zeta_1(z') \ln M_{\text{vir}}(z') dz'$
# - $\epsilon_3(z) = \int_{z_{\text{a}}}^{z} \Phi(z') \zeta_1(z') \left( \int_{z_{\text{a}}}^{z'} \Phi(u) du \right) dz'$
#
# ---
#
# ## 4. Second-Order Perturbation
#
# To include second-order effects, we consider the next-order correction $\delta(z)$, expanding $m(z)$ as:
#
# $$
# m(z) = m_0(z) \cdot e^{\epsilon(z) + \delta(z)}
# $$
#
# ### 4.1. Derivation of $\delta(z)$
#
# Starting from:
#
# $$
# \frac{dm}{dz} = \Phi(z) \cdot m(z) \left( \frac{m(z)}{M_{\text{vir}}(z)} \right)^{\zeta(z)}
# $$
#
# Substituting $m(z) = m_0(z) e^{\epsilon(z) + \delta(z)}$ and expanding as before:
#
# 1. **Equate LHS and RHS:**
#
# $$
# m_0'(z) e^{\epsilon(z) + \delta(z)} + m_0(z) e^{\epsilon(z) + \delta(z)} \left( \epsilon'(z) + \delta'(z) \right) = \Phi(z) m_0(z) e^{\epsilon(z) + \delta(z)} \exp\left[ \zeta_1(z) \left( \ln\left( \frac{m_0(z)}{M_{\text{vir}}(z)} \right) + \epsilon(z) + \delta(z) \right) \right]
# $$
#
# 2. **Simplify RHS:**
#
# Using the second-order Taylor expansion:
#
# $$
# \exp\left[ \zeta_1(z) x \right] \approx 1 + \zeta_1(z) x + \frac{1}{2} \zeta_1(z)^2 x^2
# $$
#
# Thus, the RHS becomes:
#
# $$
# \Phi(z) m_0(z) e^{\epsilon(z) + \delta(z)} \left[ 1 + \zeta_1(z) \left( \ln\left( \frac{m_0(z)}{M_{\text{vir}}(z)} \right) + \epsilon(z) + \delta(z) \right) + \frac{1}{2} \zeta_1(z)^2 \left( \ln\left( \frac{m_0(z)}{M_{\text{vir}}(z)} \right) + \epsilon(z) + \delta(z) \right)^2 \right]
# $$
#
# 3. **Subtract $m_0'(z) e^{\epsilon(z) + \delta(z)}$ from both sides:**
#
# $$
# m_0(z) e^{\epsilon(z) + \delta(z)} \left( \epsilon'(z) + \delta'(z) \right) = \Phi(z) m_0(z) e^{\epsilon(z) + \delta(z)} \left[ \zeta_1(z) \left( \ln\left( \frac{m_0(z)}{M_{\text{vir}}(z)} \right) + \epsilon(z) + \delta(z) \right) + \frac{1}{2} \zeta_1(z)^2 \left( \ln\left( \frac{m_0(z)}{M_{\text{vir}}(z)} + \epsilon(z) + \delta(z) \right)^2 \right) \right]
# $$
#
# 4. **Divide both sides by $m_0(z) e^{\epsilon(z) + \delta(z)}$:**
#
# $$
# \epsilon'(z) + \delta'(z) = \Phi(z) \left[ \zeta_1(z) \left( \ln\left( \frac{m_0(z)}{M_{\text{vir}}(z)} \right) + \epsilon(z) + \delta(z) \right) + \frac{1}{2} \zeta_1(z)^2 \left( \ln\left( \frac{m_0(z)}{M_{\text{vir}}(z)} + \epsilon(z) + \delta(z) \right)^2 \right) \right]
# $$
#
# Since $\delta(z)$ is second-order, we can neglect terms involving $\delta(z)$ on the right-hand side (third-order effect):
#
# $$
# \epsilon'(z) + \delta'(z) = \Phi(z) \left[ \zeta_1(z) \left( \ln\left( \frac{m_0(z)}{M_{\text{vir}}(z)} \right) + \epsilon(z) \right) + \frac{1}{2} \zeta_1(z)^2 \left( \ln\left( \frac{m_0(z)}{M_{\text{vir}}(z)} \right)^2 \right) \right]
# $$
#
# Subtract the first-order equation:
#
# $$
# \epsilon'(z) = \Phi(z) \zeta_1(z) \ln\left( \frac{m_0(z)}{M_{\text{vir}}(z)} \right)
# $$
#
# From both sides:
#
# $$
# \delta'(z) = \Phi(z) \zeta_1(z) \epsilon(z) + \frac{1}{2} \Phi(z) \zeta_1(z)^2 \left( \ln\left( \frac{m_0(z)}{M_{\text{vir}}(z)} \right) \right)^2
# $$
#
# ### 4.2. Integrating $\delta(z)$
#
# Integrate both sides:
#
# $$
# \delta(z) = \int_{z_{\text{a}}}^{z} \Phi(z') \zeta_1(z') \epsilon(z') dz' + \frac{1}{2} \int_{z_{\text{a}}}^{z} \Phi(z') \zeta_1(z')^2 \left( \ln\left( \frac{m_0(z')}{M_{\text{vir}}(z')} \right) \right)^2 dz'
# $$
#
# ---
#
# ## 5. Decomposition of $\delta_2(z)$
#
# The term $\delta_2(z)$ involves the square of the logarithm. By substituting $m_0(z')$, we can expand $\delta_2(z)$ explicitly.
#
# ### 5.1. Expanding the Square
#
# We have:
#
# $$
# \left( \ln\left( \frac{m_0(z')}{M_{\text{vir}}(z')} \right) \right)^2 = \left( \ln m_{\text{a}} + \int_{z_{\text{a}}}^{z'} \Phi(u) du - \ln M_{\text{vir}}(z') \right)^2
# $$
#
# Expanding the square:
#
# $$
# \begin{align*}
# \left( \ln\left( \frac{m_0(z')}{M_{\text{vir}}(z')} \right) \right)^2 &= \left( \ln m_{\text{a}} - \ln M_{\text{vir}}(z') + \int_{z_{\text{a}}}^{z'} \Phi(u) du \right)^2 \\
# &= \left( \ln m_{\text{a}} - \ln M_{\text{vir}}(z') \right)^2 + 2 \left( \ln m_{\text{a}} - \ln M_{\text{vir}}(z') \right) \int_{z_{\text{a}}}^{z'} \Phi(u) du + \left( \int_{z_{\text{a}}}^{z'} \Phi(u) du \right)^2
# \end{align*}
# $$
#
# ### 5.2. Expressing $\delta_2(z)$
#
# Substitute back into $\delta_2(z)$:
#
# $$
# \delta_2(z) = \frac{1}{2} \int_{z_{\text{a}}}^{z} \Phi(z') \zeta_1(z')^2 \left[ \left( \ln m_{\text{a}} - \ln M_{\text{vir}}(z') \right)^2 + 2 \left( \ln m_{\text{a}} - \ln M_{\text{vir}}(z') \right) \int_{z_{\text{a}}}^{z'} \Phi(u) du + \left( \int_{z_{\text{a}}}^{z'} \Phi(u) du \right)^2 \right] dz'
# $$
#
# ### 5.3. Splitting $\delta_2(z)$ into Components
#
# We can write $\delta_2(z)$ as the sum of three terms:
#
# 1. **First Term:**
#
#    $$
#    \delta_{2a}(z) = \frac{1}{2} \int_{z_{\text{a}}}^{z} \Phi(z') \zeta_1(z')^2 \left( \ln m_{\text{a}} - \ln M_{\text{vir}}(z') \right)^2 dz'
#    $$
#
# 2. **Second Term:**
#
#    $$
#    \delta_{2b}(z) = \int_{z_{\text{a}}}^{z} \Phi(z') \zeta_1(z')^2 \left( \ln m_{\text{a}} - \ln M_{\text{vir}}(z') \right) \left( \int_{z_{\text{a}}}^{z'} \Phi(u) du \right) dz'
#    $$
#
# 3. **Third Term:**
#
#    $$
#    \delta_{2c}(z) = \frac{1}{2} \int_{z_{\text{a}}}^{z} \Phi(z') \zeta_1(z')^2 \left( \int_{z_{\text{a}}}^{z'} \Phi(u) du \right)^2 dz'
#    $$
#
# ---
#
# ## 6. Final Expression for $m(z)$
#
# Including up to second-order corrections, the mass $m(z)$ is:
#
# $$
# m(z) = m_0(z) \cdot e^{\epsilon(z) + \delta(z)}
# $$
#
# Where:
#
# - $m_0(z) = m_{\text{a}} \cdot \exp\left( \int_{z_{\text{a}}}^{z} \Phi(z') dz' \right)$
# - $\epsilon(z) = \epsilon_1(z) + \epsilon_2(z) + \epsilon_3(z)$
# - $\delta(z) = \delta_1(z) + \delta_{2a}(z) + \delta_{2b}(z) + \delta_{2c}(z)$
#
# With:
#
# - $\epsilon_1(z) = \ln m_{\text{a}} \int_{z_{\text{a}}}^{z} \Phi(z') \zeta_1(z') dz'$
# - $\epsilon_2(z) = -\int_{z_{\text{a}}}^{z} \Phi(z') \zeta_1(z') \ln M_{\text{vir}}(z') dz'$
# - $\epsilon_3(z) = \int_{z_{\text{a}}}^{z} \Phi(z') \zeta_1(z') \left( \int_{z_{\text{a}}}^{z'} \Phi(u) du \right) dz'$
# - $\delta_1(z) = \int_{z_{\text{a}}}^{z} \Phi(z') \zeta_1(z') \epsilon(z') dz'$
#
# ---
#
# ## 7. Summary of Steps for Calculation
#
# **Step 1: Compute $m_0(z)$**
#
# - Compute $\Phi(z)$ over the redshift range.
# - Integrate $\Phi(z)$ from $z_{\text{a}}$ to $z$ to obtain $\int_{z_{\text{a}}}^{z} \Phi(z') dz'$.
# - Calculate $m_0(z)$.
#
# **Step 2: Compute First-Order Correction $\epsilon(z)$**
#
# - Compute $\epsilon_1(z)$, $\epsilon_2(z)$, and $\epsilon_3(z)$ separately.
# - Sum to obtain $\epsilon(z)$.
#
# **Step 3: Compute Second-Order Correction $\delta(z)$**
#
# - Compute $\delta_1(z)$ using $\epsilon(z)$.
# - Compute $\delta_{2a}(z)$, $\delta_{2b}(z)$, and $\delta_{2c}(z)$ using the expanded expressions.
# - Sum to obtain $\delta(z)$.
#
# **Step 4: Compute Final Mass $m(z)$**
#
# - Combine $m_0(z)$, $\epsilon(z)$, and $\delta(z)$ to get $m(z)$.
#
# ---
#
# ## 8. Important Notes
#
# - **Assumption of $\zeta_0 \approx 0$:** Simplifies the equations and is valid when $\zeta(z)$ is small.
# - **Validity of Perturbation Expansion:** The perturbative approach is appropriate when the corrections $\epsilon(z)$ and $\delta(z)$ are small compared to one.
# - **Neglected Terms:** Higher-order terms (third order and beyond) are neglected as they contribute insignificantly.
#
# ---
#
# ## 9. Conclusion
#
# By carefully deriving the perturbative solutions for subhalo mass evolution up to second order and explicitly expanding the terms involving $\ln m_{\text{a}}$, we have obtained a comprehensive model that accounts for tidal stripping process. This detailed derivation ensures accurate modeling and facilitates numerical implementation for further research and analysis.
#
# ---
#
# ## Appendix: N-th Order Corrections
#
# The differential equation for $m(z)$ can be expanded to higher orders to obtain more accurate solutions. Recall that the equation is:
#
# $$
# \frac{dm}{dz} = \Phi(z) \cdot m(z) \left( \frac{m(z)}{M_{\text{vir}}(z)} \right)^{\zeta(z)}
# $$
#
# or equivalently:
#
# $$
# \frac{d\ln m}{dz} = \Phi(z) \left( \frac{m(z)}{M_{\text{vir}}(z)} \right)^{\zeta(z)}
# $$
#
# Then we expand $m(z)$ as:
#
# $$
# m(z) = m_a \exp\left( \sum_{n=0}^{\infty} \epsilon_n(z) \right)
# $$
#
# or equivalently:
#
# $$
# \ln m(z) = \ln m_a + \sum_{n=0}^{\infty} \epsilon_n(z)
# $$
#
# Where $\epsilon_n(z)$ is the $n$-th order correction to the mass evolution.
#
# The LHS of the (logarithmic) differential equation can be expanded as a power series in $\epsilon_n(z)$:
#
# $$
# \begin{align*}
# \text{LHS} &= \frac{d\ln m}{dz} \\
# &= \frac{d}{dz} \left( \ln m_a + \sum_{n=0}^{\infty} \epsilon_n(z) \right) \\
# &= \sum_{n=0}^{\infty} \frac{d\epsilon_n(z)}{dz}
# \end{align*}
# $$
#
# The RHS of the (logarithmic) differential equation can be expanded as a power series in $\epsilon_n(z)$:
#
# $$
# \begin{align*}
# \text{RHS} &= \Phi(z) \left( \frac{m(z)}{M_{\text{vir}}(z)} \right)^{\zeta(z)} \\
# &= \Phi(z) \exp\left( \zeta(z) \ln\left( \frac{m(z)}{M_{\text{vir}}(z)} \right) \right) \\
# &= \Phi(z) \exp\left( \zeta(z) \left( \ln \left(\frac{m_a}{ M_{\text{vir}}(z)}\right) + \sum_{n=0}^{\infty} \epsilon_n(z) \right) \right) \\
# \end{align*}
# $$
#
# To simplify the equation, we define $\epsilon'_n(z)$ as $\epsilon'_0 = \epsilon_0 + \ln(m_a/M_{\text{vir}}(z))$ and $\epsilon'_n = \epsilon_n$ for $n > 0$. Then the RHS becomes:
#
# $$
# \text{RHS} = \Phi(z) \exp\left( \zeta(z) \sum_{n=0}^{\infty} \epsilon'_n(z) \right)
# $$
#
# The differential equation can now be written as:
#
# $$
# \sum_{n=0}^{\infty} \frac{d\epsilon_n(z)}{dz} = \Phi(z) \exp\left( \zeta(z) \sum_{n=0}^{\infty} \epsilon'_n(z) \right)
# $$
#
# We want to solve this equation order by order, so we need to expand the RHS in terms of the perturbative order.
#
# ### Expansion of the RHS
#
# Hereafter we omit the argument $z$ for simplicity. The exponential term in the RHS can be expanded as a power series in $\zeta(z)$:
#
# $$
# \begin{align*}
# \exp\left( \zeta \sum_{n=0}^{\infty} \epsilon'_n \right) &= \sum_{k=0}^{\infty} \frac{1}{k!} \left( \zeta \sum_{n=0}^{\infty} \epsilon'_n \right)^k \\
# &= \sum_{k=0}^{\infty} \frac{1}{k!} \zeta^k \left( \sum_{n=0}^{\infty} \epsilon'_n \right)^k \\
# \end{align*}
# $$
#
# Using the multinomial theorem, we obtain:
#
# $$
# \begin{align*}
# \sum_{k=0}^{\infty} \frac{1}{k!} \zeta^k \left( \sum_{n=0}^{\infty} \epsilon'_n \right)^k
# &= \sum_{k=0}^{\infty} \frac{1}{k!} \zeta^k \sum_{\sum_i{n_i} = k} \frac{k!}{n_0! n_1! n_2! \ldots} \prod_{i} {\epsilon'_i}^{n_i} \\
# \end{align*}
# $$
#
# To obtain specific perturbative order terms, we change the order of summation:
#
# $$
# \sum_{\sum_i{n_i}=k} = \sum_{m} \sum_{\substack{\sum_i{n_i}=k \\ \sum_i i \cdot n_i = m}}
# $$
#
# where $k = \sum_i n_i$ is the total order of the term and $m = \sum_i i \cdot n_i$ is the perturbative order. Then the RHS can be written as:
#
# $$
# \text{RHS} = \Phi \sum_{k=0}^{\infty}\zeta^k\sum_{m=0}^{\infty}  \sum_{\substack{\sum_i{n_i}=k \\ \sum_i i \cdot n_i = m}}\prod_{i} \frac{{\epsilon'_i}^{n_i}}{n_i!}
# $$
#
# Here we define $f_{k,m} = \sum_{\substack{\sum_i{n_i}=k \\ \sum_i i \cdot n_i = m}}\prod_i \frac{{\epsilon'_i}^{n_i}}{n_i!}$, so that the RHS can be written as:
#
# $$
# \text{RHS} = \Phi \sum_{k=0}^{\infty}\sum_{m=0}^{\infty} \zeta^k  f_{k,m}
# $$
#
# Here we note that $f_{0,0} = 1$ (corresponding to $\exp(x) = 1 + \cdots$) and $f_{0,m} = 0$ for $m>0$. In other words,
#
# $$
# f_{k,m} = \left(\text{summation of } \prod_i \frac{{\epsilon'_i}^{n_i}}{n_i!} \text{ whose perturbative order is } m \text{ and the total order is } k\right)
# $$
#
# ### Solving the Differential Equation
#
# The differential equation can now be written as:
#
# $$
# \sum_{n=0}^{\infty} \frac{d\epsilon_n}{dz} = \Phi \sum_{k=0}^{\infty}\sum_{m=0}^{\infty} \zeta^k  f_{k,m}
# $$
#
# To extract the $n$-th order term of the RHS, we change the order of summation:
#
# $$
# \sum_{k=0}^{\infty}\sum_{m=0}^{\infty}\zeta^k  f_{k,m} = \Phi \sum_{n=0}^{\infty} \sum_{m=0}^{n} \zeta^{n-m} f_{n-m,m}
# $$
#
# where $n = k + m$. Eventually, taking the $n$-th order term of each side, we obtain the $n$-th order correction to the mass evolution equation:
#
# $$
# \begin{align*}
# \frac{d\epsilon_n}{dz}
# &= \Phi\sum_{m=0}^{n} \zeta^{n-m} f_{n-m,m}
# &= \Phi\left(\zeta^n f_{n,0} + \zeta^{n-1} f_{n-1,1} + \zeta^{n-2} f_{n-2,2} + \cdots + f_{0,n}\right)
# \end{align*}
# $$
#
# Again, we remind that $f_{0,0} = 1$ and $f_{0,m} = 0$ for $m>0$. Moreover, $f_{n,m}$ depends on terms whose perturbative order is less than or equal to $m$, so that the $n$-th order correction depends on lower-order corrections. Therefore, we can solve the differential equation order by order, starting from the zeroth order.
#
# ### Example
#
# We check the first few orders of the perturbative expansion.
#
# #### The zeroth order equation
#
# $$
# \frac{d\epsilon_0}{dz} = \Phi f_{0,0} = \Phi
# $$
#
# Then we have:
#
# $$
# \epsilon_0(z) = \int_{z_a}^{z} \Phi(z') dz'
# $$
#
# #### The first order equation
#
# $$
# \begin{align*}
# \frac{d\epsilon_1}{dz}
# &= \Phi \left( \zeta f_{1,0} + \zeta^0 f_{0,1} \right) \\
# &= \Phi \zeta f_{1,0} \\
# &= \Phi \zeta \frac{\epsilon'_0}{1!}
# \end{align*}
# $$
#
# Then we have:
#
# $$
# \epsilon_1(z) = \int_{z_a}^{z} \Phi(z') \zeta(z') \epsilon'_0(z') dz'
# $$
#
# #### The second order equation
#
# $$
# \begin{align*}
# \frac{d\epsilon_2}{dz}
# &= \Phi \left( \zeta^2 f_{2,0} + \zeta f_{1,1} + \zeta^0 f_{0,2} \right) \\
# &= \Phi \zeta^2 f_{2,0} + \Phi \zeta f_{1,1} \\
# &= \Phi \zeta^2 \frac{{\epsilon'_0}^2}{2!} + \Phi \zeta \frac{\epsilon'_1}{1!}
# \end{align*}
# $$
#
# Then we have:
#
# $$
# \epsilon_2(z) = \int_{z_a}^{z} \Phi(z') \left( \zeta(z')^2 \frac{\epsilon'_0(z')^2}{2!} + \zeta(z') \epsilon'_1(z') \right) dz'
# $$
#
# #### The third order equation
#
# $$
# \begin{align*}
# \frac{d\epsilon_3}{dz}
# &= \Phi \left( \zeta^3 f_{3,0} + \zeta^2 f_{2,1} + \zeta f_{1,2} + \zeta^0 f_{0,3} \right) \\
# &= \Phi \zeta^3 f_{3,0} + \Phi \zeta^2 f_{2,1} + \Phi \zeta f_{1,2} \\
# &= \Phi \zeta^3 \frac{{\epsilon'_0}^3}{3!} + \Phi \zeta^2 \frac{\epsilon'_0 {\epsilon'_1}}{1!1!} + \Phi \zeta \frac{{\epsilon'_2}}{1!}
# \end{align*}
# $$
#
# Then we have:
#
# $$
# \epsilon_3(z) = \int_{z_a}^{z} \Phi(z') \left( \zeta(z')^3 \frac{{\epsilon'_0(z')}^3}{3!} + \zeta(z')^2 \frac{\epsilon'_0(z') \epsilon'_1(z')}{1!1!} + \zeta(z') \epsilon'_2(z') \right) dz'
# $$
#
#
# This process can be repeated for higher orders to obtain the full perturbative expansion of the mass evolution equation.

# %%
# %pip install tqdm
# Out:
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import scipy
scipy.__version__
# Out:
# '1.14.1'

# %%
import sashimi_c
import matplotlib.pyplot as plt
import numpy as np
import tqdm
import scipy
from scipy.integrate import odeint, cumulative_trapezoid

# # if scipy has cumulative_simpson, load it
if hasattr(scipy.integrate, 'cumulative_simpson'):
    from scipy.integrate import cumulative_simpson
    print('"cumulative_simpson" has been found in scipy.integrate')
    def _cumulative_simpson(y, x, *args, **kwargs):
        # NOTE: cumulative_simpson works only for increasing x, like F(x) = \int_a^x f(x') dx'.
        # However, we want to obtain \int_a^x f(x') dx' for decreasing x.
        # To do this, we rephrase the integral as follows:
        #   \int_a^x = \int_b^x - \int_b^a, where b < x < a.
        ret = cumulative_simpson(y[::-1], x=x[::-1], *args, **kwargs)[::-1]
        return ret - ret[0]
    # cumulative_simpson = _cumulative_simpson
    # cumulative_integrate = cumulative_simpson
else:
    print('No "cumulative_simpson" in scipy.integrate')
    # cumulative_integrate = cumulative_trapezoid

# cumulative_integrate = cumulative_trapezoid


class MySubhaloProperties:
    def __init__(self,M0,n_z=64):
        super().__init__()
        # self.set_integration_method("cumulative_simpson")
        self.set_integration_method("cumulative_trapezoid")
        self.n_z = n_z  # number of redshifts for integration
        self.M0 = M0

    @property
    def M0(self):
        return self._M0
    
    @M0.setter
    def M0(self, M0):
        self._M0 = M0
        self.reset_interpolation()

    def reset_interpolation(self):
        za_max = 10
        z_min = 0
        n_z = self.n_z
        _z, _eps_0 = self._eps_0(za_max, z_min, n_z)
        # _z, _eps_1 = self._eps_1(za_max, z_min, n_z)
        # _z, _eps_2 = self._eps_2(za_max, z_min, n_z)
        # _z, _eps_3 = self._eps_3(za_max, z_min, n_z)
        _z, _eps_10 = self._eps_10(za_max, z_min, n_z)
        _z, _eps_11 = self._eps_11(za_max, z_min, n_z)
        _z, _eps_20 = self._eps_20(za_max, z_min, n_z)
        _z, _eps_21 = self._eps_21(za_max, z_min, n_z)
        _z, _eps_22 = self._eps_22(za_max, z_min, n_z)
        _z, _eps_30 = self._eps_30(za_max, z_min, n_z)
        _z, _eps_31 = self._eps_31(za_max, z_min, n_z)
        _z, _eps_32 = self._eps_32(za_max, z_min, n_z)
        _z, _eps_33 = self._eps_33(za_max, z_min, n_z)
        # get interpolation function of correction functions
        # self._eps_1_interp = scipy.interpolate.interp1d(_z, _eps_1)
        # self._eps_2_interp = scipy.interpolate.interp1d(_z, _eps_2)
        # self._eps_3_interp = scipy.interpolate.interp1d(_z, _eps_3)
        # Instead of using scipy.interpolate.interp1d, we use np.interp for faster interpolation
        # self._eps_1_interp = lambda z: np.interp(z, _z[::-1], _eps_1[::-1])
        # self._eps_2_interp = lambda z: np.interp(z, _z[::-1], _eps_2[::-1])
        # self._eps_3_interp = lambda z: np.interp(z, _z[::-1], _eps_3[::-1])
        # self.eps_1 = lambda _za, _z: self._eps_1_interp(_z) - self._eps_1_interp(_za)
        # self.eps_2 = lambda _za, _z: self._eps_2_interp(_z) - self._eps_2_interp(_za)
        # self.eps_3 = lambda _za, _z: self._eps_3_interp(_z) - self._eps_3_interp(_za)
        self._eps_0_interp = lambda z: np.interp(z, _z[::-1], _eps_0[::-1])
        self._eps_10_interp = lambda z: np.interp(z, _z[::-1], _eps_10[::-1])
        self._eps_11_interp = lambda z: np.interp(z, _z[::-1], _eps_11[::-1])
        self._eps_20_interp = lambda z: np.interp(z, _z[::-1], _eps_20[::-1])
        self._eps_21_interp = lambda z: np.interp(z, _z[::-1], _eps_21[::-1])
        self._eps_22_interp = lambda z: np.interp(z, _z[::-1], _eps_22[::-1])
        self._eps_30_interp = lambda z: np.interp(z, _z[::-1], _eps_30[::-1])
        self._eps_31_interp = lambda z: np.interp(z, _z[::-1], _eps_31[::-1])
        self._eps_32_interp = lambda z: np.interp(z, _z[::-1], _eps_32[::-1])
        self._eps_33_interp = lambda z: np.interp(z, _z[::-1], _eps_33[::-1])
        self.eps_0 = lambda _za, _z: self._eps_0_interp(_z) - self._eps_0_interp(_za)
        self.eps_10 = lambda _za, _z: self._eps_10_interp(_z) - self._eps_10_interp(_za)
        self.eps_11 = lambda _za, _z: self._eps_11_interp(_z) - self._eps_11_interp(_za)
        self.eps_20 = lambda _za, _z: self._eps_20_interp(_z) - self._eps_20_interp(_za)
        self.eps_21 = lambda _za, _z: self._eps_21_interp(_z) - self._eps_21_interp(_za)
        self.eps_22 = lambda _za, _z: self._eps_22_interp(_z) - self._eps_22_interp(_za)
        self.eps_30 = lambda _za, _z: self._eps_30_interp(_z) - self._eps_30_interp(_za)
        self.eps_31 = lambda _za, _z: self._eps_31_interp(_z) - self._eps_31_interp(_za)
        self.eps_32 = lambda _za, _z: self._eps_32_interp(_z) - self._eps_32_interp(_za)
        self.eps_33 = lambda _za, _z: self._eps_33_interp(_z) - self._eps_33_interp(_za)
        


    def set_integration_method(self, method):
        self.cumulative_integrate = {
            "cumulative_trapezoid" : cumulative_trapezoid,
            "cumulative_simpson" : _cumulative_simpson
        }[method]
        print(f"Integration method: {method}")

    def Mzvir(self,z):
        Mz200 = self.Mzzi(self.M0,z,0.)
        Mvir = self.Mvir_from_M200_fit(Mz200,z)
        return Mvir

    def AMz(self,z):
        log10a = (-0.0003*np.log10(self.Mzvir(z)/self.Msun)+0.02)*z \
                        +(0.011*np.log10(self.Mzvir(z)/self.Msun)-0.354)
        return 10.**log10a

    def zetaMz(self,z):
        return (0.00012*np.log10(self.Mzvir(z)/self.Msun)-0.0033)*z \
                    +(-0.0011*np.log10(self.Mzvir(z)/self.Msun)+0.026)

    def tdynz(self,z):
        Oz_z = self.OmegaM*(1.+z)**3/self.g(z)
        return 1.628/self.h*(self.Delc(Oz_z-1.)/178.0)**-0.5/(self.Hubble(z)/self.H0)*1.e9*self.yr

    def msolve(self,m, z):
        return self.AMz(z)*(m/self.tdynz(z))*(m/self.Mzvir(z))**self.zetaMz(z)/(self.Hubble(z)*(1+z))

    def subhalo_mass_stripped_odeint(self,ma,za,z,n_z=64,**kwargs):
        zcalc = np.linspace(za,z,n_z)
        return zcalc,odeint(self.msolve,ma,zcalc,**kwargs)

    def Phi(self,z):
        """ subhalo stripping factor assuming zetaMz(z) = 0.
        The stripping rate dm/dt is given by
          dm/dt(z) = m(z) * Phi(z) * (m(z)/Mzvir(z))**zetaMz(z)
        """
        return self.AMz(z)/self.tdynz(z)/self.Hubble(z)/(1+z)

    # def subhalo_mass_stripped_pert0(self,ma,za,z,n_z=64):
    #     """ calculate subhalo mass stripping using perturbative method.
    #     Here we assume zetaMz is almost 0.
    #     """
    #     _z = np.linspace(za,z,n_z)
    #     integrand = self.Phi(_z)
    #     int_factor = self.cumulative_integrate(integrand,x=_z,initial=0)
    #     return _z, ma*np.exp(int_factor)


    # def _eps_1(self,za,z,n_z=64):
    #     """ calculate epsilon1 """
    #     _z = np.linspace(za,z,n_z)
    #     Phi_z = self.Phi(_z)
    #     zeta1_z = self.zetaMz(_z)
    #     integrand = Phi_z * zeta1_z
    #     return _z, self.cumulative_integrate(integrand,x=_z,initial=0)

    # def _eps_2(self,za,z,n_z=64):
    #     """ calculate epsilon2 """
    #     _z = np.linspace(za,z,n_z)
    #     Phi_z = self.Phi(_z)
    #     zeta1_z = self.zetaMz(_z)
    #     ln_Mvir_z = np.log(self.Mzvir(_z))
    #     integrand = - Phi_z * zeta1_z * ln_Mvir_z
    #     return _z, self.cumulative_integrate(integrand,x=_z,initial=0)

    # def _eps_3(self,za,z,n_z=64):
    #     """ calculate epsilon3 """
    #     _z = np.linspace(za,z,n_z)
    #     Phi_z = self.Phi(_z)
    #     zeta1_z = self.zetaMz(_z)
    #     int_Phi = self.cumulative_integrate(Phi_z,x=_z,initial=0)
    #     integrand = Phi_z * zeta1_z * int_Phi
    #     return _z, self.cumulative_integrate(integrand,x=_z,initial=0)

    def _eps_0(self,za,z,n_z=64):
        """ calculate epsilon0.
        
        Returns
        -------
        _z : array
            redshift array
        eps0 : array
            epsilon0 array.
        """
        _z = np.linspace(za,z,n_z)
        Phi_z = self.Phi(_z)
        return _z, self.cumulative_integrate(Phi_z,x=_z,initial=0)

    def _eps_10(self,za,z,n_z=64):
        """ calculate epsilon10.
        
        Returns
        -------
        _z : array
            redshift array
        eps10 : array
            epsilon10 array.
        """
        _z, eps_0 = self._eps_0(za,z,n_z)
        Phi_z = self.Phi(_z)
        zeta_z = self.zetaMz(_z)
        ln_Mvir_z = np.log(self.Mzvir(_z))
        integrand = Phi_z * (eps_0 - ln_Mvir_z) * zeta_z
        return _z, self.cumulative_integrate(integrand,x=_z,initial=0)
    
    def _eps_11(self,za,z,n_z=64):
        """ calculate epsilon11.
        
        Returns
        -------
        _z : array
            redshift array
        eps11 : array
            epsilon11 array.
        """
        _z = np.linspace(za,z,n_z)
        Phi_z = self.Phi(_z)
        zeta_z = self.zetaMz(_z)
        integrand = Phi_z * zeta_z
        return _z, self.cumulative_integrate(integrand,x=_z,initial=0)
    
    def _eps_20(self,za,z,n_z=64):
        """ calculate epsilon20.
        
        Returns
        -------
        _z : array
            redshift array
        eps20 : array
            epsilon20 array.
        """
        _z, eps_0 = self._eps_0(za,z,n_z)
        _, eps_10 = self._eps_10(za,z,n_z)
        Phi_z = self.Phi(_z)
        zeta_z = self.zetaMz(_z)
        ln_Mvir_z = np.log(self.Mzvir(_z))
        integrand = Phi_z * zeta_z **2 * (eps_0 - ln_Mvir_z)**2 /2 + Phi_z * zeta_z * eps_10
        return _z, self.cumulative_integrate(integrand,x=_z,initial=0)
    
    def _eps_21(self,za,z,n_z=64):
        """ calculate epsilon21.
        
        Returns
        -------
        _z : array
            redshift array
        eps21 : array
            epsilon21 array.
        """
        _z, eps_0 = self._eps_0(za,z,n_z)
        _, eps_11 = self._eps_11(za,z,n_z)
        Phi_z = self.Phi(_z)
        zeta_z = self.zetaMz(_z)
        ln_Mvir_z = np.log(self.Mzvir(_z))
        integrand = Phi_z * zeta_z**2 * (eps_0 - ln_Mvir_z) + Phi_z * zeta_z * eps_11
        return _z, self.cumulative_integrate(integrand,x=_z,initial=0)

    def _eps_22(self,za,z,n_z=64):
        """ calculate epsilon22.
        
        Returns
        -------
        _z : array
            redshift array
        eps22 : array
            epsilon22 array.
        """
        _z = np.linspace(za,z,n_z)
        Phi_z = self.Phi(_z)
        zeta_z = self.zetaMz(_z)
        integrand = Phi_z * zeta_z**2 / 2
        return _z, self.cumulative_integrate(integrand,x=_z,initial=0)
    
    def _eps_30(self, za, z, n_z=64):
        """ calculate epsilon30. 
        
        Returns
        -------
        _z : array
            redshift array
        eps30 : array
            epsilon30 array.
        """
        _z, eps_0 = self._eps_0(za, z, n_z)
        _, eps_10 = self._eps_10(za, z, n_z)
        _, eps_20 = self._eps_20(za, z, n_z)
        Phi_z = self.Phi(_z)
        zeta_z = self.zetaMz(_z)
        ln_Mvir_z = np.log(self.Mzvir(_z))
        integrand = (Phi_z * (eps_0 - ln_Mvir_z)**3 * zeta_z**3 / 6.0
                     + Phi_z * (eps_0 - ln_Mvir_z) * eps_10 * (zeta_z**2)
                     + Phi_z * eps_20 * zeta_z)
        return _z, self.cumulative_integrate(integrand, x=_z, initial=0)


    def _eps_31(self, za, z, n_z=64):
        """  calculate epsilon31.
        
        Returns
        -------
        _z : array
            redshift array
        eps31 : array
            epsilon31 array.
        """
        _z, eps_0 = self._eps_0(za, z, n_z)
        _, eps_10 = self._eps_10(za, z, n_z)
        _, eps_11 = self._eps_11(za, z, n_z)
        _, eps_21 = self._eps_21(za, z, n_z)
        Phi_z = self.Phi(_z)
        zeta_z = self.zetaMz(_z)
        ln_Mvir_z = np.log(self.Mzvir(_z))
        integrand = (Phi_z * (eps_0 - ln_Mvir_z)**2 * (zeta_z**3) / 2.0
                        + Phi_z * eps_10 * (zeta_z**2)
                        + Phi_z * eps_21 * zeta_z
                        + Phi_z * (eps_0 - ln_Mvir_z) * eps_11 * (zeta_z**2))
        return _z, self.cumulative_integrate(integrand, x=_z, initial=0)


    def _eps_32(self, za, z, n_z=64):
        """ calculate epsilon32.

        Returns
        -------
        _z : array
            redshift array
        eps32 : array
            epsilon32 array.
        """
        _z, eps_0 = self._eps_0(za, z, n_z)
        _, eps_11 = self._eps_11(za, z, n_z)
        _, eps_22 = self._eps_22(za, z, n_z)
        Phi_z = self.Phi(_z)
        zeta_z = self.zetaMz(_z)
        ln_Mvir_z = np.log(self.Mzvir(_z))
        integrand = (Phi_z * (eps_0 - ln_Mvir_z) * (zeta_z**3) / 2.0
                        + Phi_z * eps_11 * (zeta_z**2)
                        + Phi_z * eps_22 * zeta_z)
        return _z, self.cumulative_integrate(integrand, x=_z, initial=0)


    def _eps_33(self, za, z, n_z=64):
        """ calculate epsilon33.

        Returns
        -------
        _z : array
            redshift array
        eps33 : array
            epsilon33 array.
        """
        _z = np.linspace(za, z, n_z)
        Phi_z = self.Phi(_z)
        zeta_z = self.zetaMz(_z)
        integrand = Phi_z * (zeta_z**3) / 6.0
        return _z, self.cumulative_integrate(integrand, x=_z, initial=0)


    # def subhalo_mass_stripped_pert1(self, ma, za, z, n_z=64):
    #     """ calculate subhalo mass stripping using perturbative method.
    #     The subhalo mass can be written as
    #     m(z) = m0(z) * exp(epsilon(z))
    #     where m0(z) is the zeroth-order mass and epsilon(z) is the perturbative correction, given by
    #     eplison(z) = epsilon1' + epsilon2 + epsilon3
    #       = (\ln{m_a} * epsilon1 + epsilon2 + epsilon3
    #     where
    #     - \epsilon_1 = \int_{z_a}^{z} \Phi(z{\prime}) \cdot \zeta_1(z{\prime}) dz{\prime}
    #     - \epsilon_2 = - \int_{z_a}^{z} \Phi(z{\prime}) \cdot \zeta_1(z{\prime}) \cdot \ln M_{\text{vir}}(z{\prime}) dz{\prime}
    #     - \epsilon_3 = \int_{z_a}^{z} \Phi(z{\prime}) \cdot \zeta_1(z{\prime}) \left( \int_{z_a}}^{z{\prime}} \Phi(u) du \right) dz{\prime}
    #     """
    #     _z,m0 = self.subhalo_mass_stripped_pert0(ma,za,z,n_z)
    #     # _z,eps1 = self._eps_1(za,z,n_z)
    #     # _z,eps2 = self._eps_2(za,z,n_z)
    #     # _z,eps3 = self._eps_3(za,z,n_z)
    #     eps1 = self.eps_1(za,_z)
    #     eps2 = self.eps_2(za,_z)
    #     eps3 = self.eps_3(za,_z)
    #     return _z, m0*np.exp(np.log(ma)*eps1+eps2+eps3)


    # def subhalo_mass_stripped_pert2(self, ma, za, z, n_z=64):
    #     """Calculate subhalo mass stripping including second-order perturbation."""
    #     # Create redshift array
    #     _z = np.linspace(za, z, n_z)

    #     # Step 1: Compute Phi(z), zeta1(z), and m0(z)
    #     Phi_z = self.Phi(_z)
    #     zeta1_z = self.zetaMz(_z)  # Since zeta0 ≈ 0
    #     int_Phi = self.cumulative_integrate(Phi_z, x=_z, initial=0)
    #     m0_z = ma * np.exp(int_Phi)

    #     # Step 2: Compute ln(m0(z)/Mvir(z))
    #     ln_m0_over_Mvir = np.log(m0_z / self.Mzvir(_z))

    #     # Step 3: Compute epsilon(z) (First-order correction)
    #     # _z, eps1 = self._eps_1(za, z, n_z)
    #     # _z, eps2 = self._eps_2(za, z, n_z)
    #     # _z, eps3 = self._eps_3(za, z, n_z)
    #     eps1 = self.eps_1(za, _z)
    #     eps2 = self.eps_2(za, _z)
    #     eps3 = self.eps_3(za, _z)
    #     epsilon_total = np.log(ma) * eps1 + eps2 + eps3

    #     # Step 4: Compute delta(z) (second-order correction)
    #     # Compute delta_1(z)
    #     integrand_delta1 = Phi_z * zeta1_z * epsilon_total
    #     delta1 = self.cumulative_integrate(integrand_delta1, x=_z, initial=0)

    #     # Compute delta_2(z)
    #     integrand_delta2 = 0.5 * Phi_z * zeta1_z**2 * ln_m0_over_Mvir**2
    #     delta2 = self.cumulative_integrate(integrand_delta2, x=_z, initial=0)

    #     # Total delta(z)
    #     delta_z = delta1 + delta2

    #     # Step 5: Compute the final mass m(z) including second-order correction
    #     m_z = m0_z * np.exp(epsilon_total + delta_z)

    #     return _z, m_z
    
    def subhalo_mass_stripped(self,ma,za,z,n_z=64,method="odeint",**kwargs):
        """ calculate subhalo mass stripping.
        
        Parameters
        ----------
        ma : float
            initial subhalo mass.
        za : float
            initial redshift.
        z : float
            final redshift.
        n_z : int, optional
            number of redshifts for integration.
        method : str, optional
            method to calculate the subhalo mass stripping.
            - "odeint" : use odeint to solve the differential equation.
            - "pert0" : use perturbative method with zeroth-order correction.
            - "pert1" : use perturbative method with first-order correction.
            - "pert2" : use perturbative method with second-order correction.
            - "pert2_shanks" : use perturbative method with second-order correction and Shanks transformation.
            - "pert3" : use perturbative method with third-order correction.
        kwargs : dict, optional
            additional arguments for the odeint function.

        Returns
        -------
        zcalc : array
            redshift array.
        mcalc : array
            subhalo mass array.
        """
        if method[:4] == "pert":
            _z = np.linspace(za, z, n_z)
        match method:
            case "odeint":
                return self.subhalo_mass_stripped_odeint(ma,za,z,n_z,**kwargs)
            case "pert0":
                return _z, self.subhalo_mass_stripped_pert0(ma,za,_z)
            case "pert1":
                return _z, self.subhalo_mass_stripped_pert1(ma,za,_z)
            case "pert2":
                return _z, self.subhalo_mass_stripped_pert2(ma,za,_z)
            case "pert2_shanks":
                return _z, self.subhalo_mass_stripped_pert2_shanks(ma,za,_z)
            case "pert3":
                return _z, self.subhalo_mass_stripped_pert3(ma,za,_z)
            case _:
                raise ValueError(f"Invalid method: {method}")


    def subhalo_mass_stripped_pert0(self, ma, za, z):
        """Calculate subhalo mass stripping using zeroth-order perturbation."""
        eps_0 = self.eps_0(za, z)
        return ma * np.exp(eps_0)
    
    def subhalo_mass_stripped_pert1(self, ma, za, z):
        """Calculate subhalo mass stripping using first-order perturbation."""
        eps_0 = self.eps_0(za, z)
        eps_10 = self.eps_10(za, z)
        eps_11 = self.eps_11(za, z)
        ln_ma = np.log(ma)
        eps = (eps_0 
               + eps_10 + ln_ma * eps_11)
        return ma * np.exp(eps)
    
    def subhalo_mass_stripped_pert2(self, ma, za, z):
        """Calculate subhalo mass stripping using second-order perturbation."""
        eps_0 = self.eps_0(za, z)
        eps_10 = self.eps_10(za, z)
        eps_11 = self.eps_11(za, z)
        eps_20 = self.eps_20(za, z)
        eps_21 = self.eps_21(za, z)
        eps_22 = self.eps_22(za, z)
        ln_ma = np.log(ma)
        eps = (eps_0 
               + eps_10 + ln_ma * eps_11 
               + eps_20 + ln_ma * eps_21 + ln_ma**2 * eps_22)
        return ma * np.exp(eps)
    
    def subhalo_mass_stripped_pert2_shanks(self, ma, za, z):
        """Calculate subhalo mass stripping using second-order perturbation with Shanks transformation."""
        eps_0 = self.eps_0(za, z)
        eps_10 = self.eps_10(za, z)
        eps_11 = self.eps_11(za, z)
        eps_20 = self.eps_20(za, z)
        eps_21 = self.eps_21(za, z)
        eps_22 = self.eps_22(za, z)
        ln_ma = np.log(ma)
        # NOTE: Shanks transformation
        # For A_n = \sum_{i=0}^{n} a_i, the Shanks transformation is given by
        #  S_n = A_{n+1} - (A_{n+1} - A_n)^2 / (A_{n+1} - 2A_n + A_{n-1})
        #      = A_{n+1} - (A_{n+1} - A_n)^2 / ((A_{n+1} - A_n) - (A_n - A_{n-1}))
        # Since A_n = \sum_{i=0}^{n} a_i, we can write
        #  S_n = A_{n+1} - a_{n+1}^2 / (a_{n+1} - a_n)
        # In our case, we calculate the epsilon as eps = \sum_{i=0}^{n} eps_i.
        # Therefore, we can apply Shanks transformation to eps up to the second order as follows:
        # S_2 = (eps_0 + eps_1 + eps_2) - eps_2^2 / (eps_2 - eps_1)
        eps_1 = eps_10 + ln_ma * eps_11
        eps_2 = eps_20 + ln_ma * eps_21 + ln_ma**2 * eps_22
        eps_2m1 = (eps_20 - eps_10) + ln_ma * (eps_21 - eps_11) + ln_ma**2 * eps_22
        eps_shanks = - eps_2**2 / eps_2m1
        eps_shanks = np.where(np.isnan(eps_shanks), 0, eps_shanks)
        # When the correction is too small, the Shanks transformation may not be stable.
        eps_shanks = np.where(np.abs((eps_1+eps_2)/eps_0) < 0.02, 0, eps_shanks)
        eps = eps_0 + eps_1 + eps_2 + eps_shanks
        # import pandas as pd
        # df = pd.DataFrame({'z': _z, 'eps_0': eps_0, 'eps_1': eps_1, 'eps_2': eps_2, 'eps_shanks': eps_shanks, 'eps': eps})
        # display(df[(df['z'] > 4) & (df['z'] < 6)])
        return ma * np.exp(eps)
    
    def subhalo_mass_stripped_pert3(self, ma, za, z):
        """Calculate subhalo mass stripping using third-order perturbation."""
        eps_0 = self.eps_0(za, z)
        eps_10 = self.eps_10(za, z)
        eps_11 = self.eps_11(za, z)
        eps_20 = self.eps_20(za, z)
        eps_21 = self.eps_21(za, z)
        eps_22 = self.eps_22(za, z)
        eps_30 = self.eps_30(za, z)
        eps_31 = self.eps_31(za, z)
        eps_32 = self.eps_32(za, z)
        eps_33 = self.eps_33(za, z)
        ln_ma = np.log(ma)
        eps = (eps_0 
               + eps_10 + ln_ma * eps_11 
               + eps_20 + ln_ma * eps_21 + ln_ma**2 * eps_22
               + eps_30 + ln_ma * eps_31 + ln_ma**2 * eps_32 + ln_ma**3 * eps_33)
        # import pandas as pd
        # df = pd.DataFrame({
        #     'z': _z,
        #     'eps_0': eps_0,
        #     'eps_10': eps_10,
        #     'eps_11': eps_11,
        #     'eps_20': eps_20,
        #     'eps_21': eps_21,
        #     'eps_22': eps_22,
        #     'eps_30': eps_30,
        #     'eps_31': eps_31,
        #     'eps_32': eps_32,
        #     'eps_33': eps_33,
        #     'eps': eps
        # })
        # display(df)
        return ma * np.exp(eps)

sp = MySubhaloProperties(M0=1.e12)
# Out:
# "cumulative_simpson" has been found in scipy.integrate
# Integration method: cumulative_trapezoid
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 562
#     544         # import pandas as pd
#     545         # df = pd.DataFrame({
#     546         #     'z': _z,
#    (...)
#     558         # })
#     559         # display(df)
#     560         return ma * np.exp(eps)
# --> 562 sp = MySubhaloProperties(M0=1.e12)
#
# Cell In[1], line 34, in MySubhaloProperties.__init__(self, M0, n_z)
#      32 self.set_integration_method("cumulative_trapezoid")
#      33 self.n_z = n_z  # number of redshifts for integration
# ---> 34 self.M0 = M0
#
# Cell In[1], line 43, in MySubhaloProperties.M0(self, M0)
#      40 @M0.setter
#      41 def M0(self, M0):
#      42     self._M0 = M0
# ---> 43     self.reset_interpolation()
#
# ...

# %%
import tqdm
# plot subhalo_mass_stripped
sp = MySubhaloProperties(M0=1.e12)
# for log10_M0 in tqdm.trange(8,16,2): 
#     sp.M0 = 10**log10_M0*sp.Msun
#     ma = 1.e8*sp.Msun
#     za = 10.
#     z = 0.
#     _z,_m = sp.subhalo_mass_stripped(ma,za,z)
#     plt.plot(_z,_m/sp.Msun,label='M0 = '+str(sp.M0/sp.Msun))
#     _z,_m = sp.subhalo_mass_stripped_pert0(ma,za,z)
#     # get current lines color
#     color = plt.gca().lines[-1].get_color()
#     plt.plot(_z,_m/sp.Msun,label='M0 = '+str(sp.M0/sp.Msun)+' pert0',color=color,linestyle='--')
#     _z,_m = sp.subhalo_mass_stripped_pert1(ma,za,z)
#     # get current lines color
#     color = plt.gca().lines[-1].get_color()
#     plt.plot(_z,_m/sp.Msun,label='M0 = '+str(sp.M0/sp.Msun)+' pert1',color=color,linestyle='-.')
# plt.xlabel('z')
# plt.ylabel('m')
# plt.yscale('log')
# plt.legend()
# plt.show()
sp.set_integration_method("cumulative_simpson")
sp.reset_interpolation()
# not in a single plot, but in separate 2x2 plots
for _ma in [1.e-6, 1.e-2, 1.e2, 1.e6]:
    fig, axs = plt.subplots(2,2,figsize=(10,10))
    axs = axs.flatten()
    ma = _ma*sp.Msun
    za = 10.
    z = 0.
    for i,log10_M0 in enumerate([8,10,12,14]): 
        sp.M0 = 10**log10_M0*sp.Msun
        _z,_m = sp.subhalo_mass_stripped(ma,za,z, n_z=640)
        axs[i].plot(_z,_m/sp.Msun,label=f'exact',color='black', linestyle='--')
        _z,_m = sp.subhalo_mass_stripped(ma,za,z, n_z=640,rtol=1.e-10,atol=1.e-10)
        axs[i].plot(_z,_m/sp.Msun,label=f'exact (accurate)',color='black')
        # _z,_m = sp.subhalo_mass_stripped_pert0(ma,za,z)
        # _z,_m = sp.subhalo_mass_stripped_pert0(ma,za,z, n_z=640)
        _z, _m = sp.subhalo_mass_stripped(ma,za,z, n_z=640, method="pert0")
        axs[i].plot(_z,_m/sp.Msun,label=f'0th',linestyle='--')
        # _z,_m = sp.subhalo_mass_stripped_pert1(ma,za,z)
        # _z,_m = sp.subhalo_mass_stripped_pert1(ma,za,z, n_z=640)
        _z,_m = sp.subhalo_mass_stripped(ma,za,z, n_z=640, method="pert1")
        axs[i].plot(_z,_m/sp.Msun,label=f'1st',linestyle='--')
        # _z,_m = sp.subhalo_mass_stripped_pert2(ma,za,z)
        # _z,_m = sp.subhalo_mass_stripped_pert2(ma,za,z, n_z=640)
        _z,_m = sp.subhalo_mass_stripped(ma,za,z, n_z=640, method="pert2")
        axs[i].plot(_z,_m/sp.Msun,label=f'2nd',linestyle='--')
        # _z,_m = sp.subhalo_mass_stripped_pert2_shanks(ma,za,z, n_z=640)
        _z,_m = sp.subhalo_mass_stripped(ma,za,z, n_z=640, method="pert2_shanks")
        axs[i].plot(_z,_m/sp.Msun,label=f'2nd (Shanks)',linestyle='--')
        # _z,_m = sp.subhalo_mass_stripped_pert3(ma,za,z, n_z=640)
        _z,_m = sp.subhalo_mass_stripped(ma,za,z, n_z=640, method="pert3")
        axs[i].plot(_z,_m/sp.Msun,label=f'3rd',linestyle='--')
        # print(_m)
        axs[i].set_xlabel('z')
        axs[i].set_ylabel('m')
        axs[i].set_yscale('log')
        axs[i].legend()
        axs[i].set_title(f"M0 = {sp.M0/sp.Msun:.1e} Msun")
    plt.suptitle(f"ma = {ma/sp.Msun:.1e}, za = {za}, z = {z}")
    plt.show()
# Out:
# Integration method: cumulative_trapezoid
# Integration method: cumulative_simpson

# %%
# plot relativistic error 2x2 plots
sp = MySubhaloProperties(M0=1.e12)
sp.set_integration_method("cumulative_simpson")
sp.reset_interpolation()
for _ma in [1.e-6, 1.e-2, 1.e2, 1.e6]:
    fig, axs = plt.subplots(2,2,figsize=(10,10),sharey=True)
    axs = axs.flatten()
    ma = _ma*sp.Msun
    za = 10.
    z = 0.
    for i,log10_M0 in enumerate([8,10,12,14]): 
        sp.M0 = 10**log10_M0*sp.Msun
        _z,_m = sp.subhalo_mass_stripped(ma,za,z,rtol=1e-12,atol=1e-12)
        _m = _m[:,0]
        # _z,_m_pert0 = sp.subhalo_mass_stripped_pert0(ma,za,z)
        # _z,_m_pert1 = sp.subhalo_mass_stripped_pert1(ma,za,z)
        # _z,_m_pert2 = sp.subhalo_mass_stripped_pert2(ma,za,z)
        _z,_m_default = sp.subhalo_mass_stripped(ma,za,z)
        _m_default = _m_default[:,0]
        # _z,_m_pert0 = sp.subhalo_mass_stripped_pert0(ma,za,z)
        # _z,_m_pert1 = sp.subhalo_mass_stripped_pert1(ma,za,z)
        # _z,_m_pert2 = sp.subhalo_mass_stripped_pert2(ma,za,z)
        # _z,_m_pert2_shanks = sp.subhalo_mass_stripped_pert2_shanks(ma,za,z)
        # _z,_m_pert3 = sp.subhalo_mass_stripped_pert3(ma,za,z)
        _z,_m_pert0 = sp.subhalo_mass_stripped(ma,za,z, method="pert0")
        _z,_m_pert1 = sp.subhalo_mass_stripped(ma,za,z, method="pert1")
        _z,_m_pert2 = sp.subhalo_mass_stripped(ma,za,z, method="pert2")
        _z,_m_pert2_shanks = sp.subhalo_mass_stripped(ma,za,z, method="pert2_shanks")
        _z,_m_pert3 = sp.subhalo_mass_stripped(ma,za,z, method="pert3")
        axs[i].plot(_z,(_m_default)/_m,label="exact (default)",color='black')
        axs[i].plot(_z,(_m_pert0)/_m,label="0th")
        axs[i].plot(_z,(_m_pert1)/_m,label="1st")
        axs[i].plot(_z,(_m_pert2)/_m,label="2nd")
        axs[i].plot(_z,(_m_pert2_shanks)/_m,label="2nd (Shanks)")
        axs[i].plot(_z,(_m_pert3)/_m,label="3rd")
        axs[i].set_xlabel('z')
        axs[i].set_ylabel('relative error: m(z)/m(z)_exact')
        axs[i].set_yscale('log')
        axs[i].legend()
        axs[i].set_title(f"M0 = {sp.M0/sp.Msun:.1e} Msun")
        print("="*20)
        print(f"M0 = {sp.M0/sp.Msun:.1e} Msun")
        print(f"ma = {ma/sp.Msun:.1e} Msun")
        print(f"maximim Relative Errors")
        print(f"- default (%): {np.max(np.abs((_m_default-_m)/_m))*100:.2f}")
        print(f"- 0th (%): {np.max(np.abs((_m_pert0-_m)/_m))*100:.2f}")
        print(f"- 1st (%): {np.max(np.abs((_m_pert1-_m)/_m))*100:.2f}")
        print(f"- 2nd (%): {np.max(np.abs((_m_pert2-_m)/_m))*100:.2f}")
        print(f"- 2nd (Shanks) (%): {np.max(np.abs((_m_pert2_shanks-_m)/_m))*100:.2f}")
        print(f"- 3rd (%): {np.max(np.abs((_m_pert3-_m)/_m))*100:.2f}")
    plt.suptitle(f"ma = {ma/sp.Msun:.1e}, za = {za}, z = {z}")
    plt.tight_layout()
    plt.show()
# Out:
# Integration method: cumulative_trapezoid
# Integration method: cumulative_simpson
# ...
# M0 = 1.0e+08 Msun
# ma = 1.0e-06 Msun
# maximim Relative Errors
# - default (%): 25.62
# - 0th (%): 88.70
# - 1st (%): 98.92
# - 2nd (%): 16.47
# - 2nd (Shanks) (%): 2.18
# - 3rd (%): 5.09
# ...
# M0 = 1.0e+10 Msun
# ma = 1.0e-06 Msun
# maximim Relative Errors
# - default (%): 24.79
# - 0th (%): 89.17
# - 1st (%): 99.78
# - 2nd (%): 15.93
# - 2nd (Shanks) (%): 2.50
# - 3rd (%): 4.68
# ...
# M0 = 1.0e+12 Msun
# ma = 1.0e-06 Msun
# maximim Relative Errors
# - default (%): 25.71
# - 0th (%): 88.96
# - 1st (%): 92.83
# - 2nd (%): 14.19
# - 2nd (Shanks) (%): 2.59
# - 3rd (%): 3.82
# ...
# M0 = 1.0e+14 Msun
# ma = 1.0e-06 Msun
# maximim Relative Errors
# - default (%): 29.18
# - 0th (%): 88.31
# - 1st (%): 80.17
# - 2nd (%): 11.65
# - 2nd (Shanks) (%): 2.37
# - 3rd (%): 2.79
# ...
# M0 = 1.0e+08 Msun
# ma = 1.0e-02 Msun
# maximim Relative Errors
# - default (%): 0.04
# - 0th (%): 82.48
# - 1st (%): 52.75
# - 2nd (%): 8.78
# ...

# %%
# plot relativistic error 2x2 plots
sp = MySubhaloProperties(M0=1.e12)
# sp.set_integration_method("cumulative_trapezoid")
# sp.reset_interpolation()
for _ma in [1.e-6, 1.e-2, 1.e2, 1.e6]:
    fig, axs = plt.subplots(2,2,figsize=(10,10),sharey=True)
    axs = axs.flatten()
    ma = _ma*sp.Msun
    za = 10.
    z = 0.
    for i,log10_M0 in enumerate([8,10,12,14]): 
        sp.M0 = 10**log10_M0*sp.Msun
        _z,_m = sp.subhalo_mass_stripped(ma,za,z,rtol=1e-12,atol=1e-12)
        _m = _m[:,0]
        # _z,_m_pert0 = sp.subhalo_mass_stripped_pert0(ma,za,z)
        # _z,_m_pert1 = sp.subhalo_mass_stripped_pert1(ma,za,z)
        # _z,_m_pert2 = sp.subhalo_mass_stripped_pert2(ma,za,z)
        _z,_m_default = sp.subhalo_mass_stripped(ma,za,z)
        _m_default = _m_default[:,0]
        # _z,_m_pert0 = sp.subhalo_mass_stripped_pert0(ma,za,z)
        # _z,_m_pert1 = sp.subhalo_mass_stripped_pert1(ma,za,z)
        # _z,_m_pert2 = sp.subhalo_mass_stripped_pert2(ma,za,z)
        # _z,_m_pert2_shanks = sp.subhalo_mass_stripped_pert2_shanks(ma,za,z)
        # _z,_m_pert3 = sp.subhalo_mass_stripped_pert3(ma,za,z)
        _z,_m_pert0 = sp.subhalo_mass_stripped(ma,za,z, method="pert0")
        _z,_m_pert1 = sp.subhalo_mass_stripped(ma,za,z, method="pert1")
        _z,_m_pert2 = sp.subhalo_mass_stripped(ma,za,z, method="pert2")
        _z,_m_pert2_shanks = sp.subhalo_mass_stripped(ma,za,z, method="pert2_shanks")
        _z,_m_pert3 = sp.subhalo_mass_stripped(ma,za,z, method="pert3")
        axs[i].plot(_z,(_m_default)/_m,label="exact (default)",color='black')
        axs[i].plot(_z,(_m_pert0)/_m,label="0th")
        axs[i].plot(_z,(_m_pert1)/_m,label="1st")
        axs[i].plot(_z,(_m_pert2)/_m,label="2nd")
        axs[i].plot(_z,(_m_pert2_shanks)/_m,label="2nd (Shanks)")
        axs[i].plot(_z,(_m_pert3)/_m,label="3rd")
        axs[i].set_xlabel('z')
        axs[i].set_ylabel('relative error: m(z)/m(z)_exact')
        axs[i].set_yscale('log')
        axs[i].legend()
        axs[i].set_title(f"M0 = {sp.M0/sp.Msun:.1e} Msun")
        print("="*20)
        print(f"M0 = {sp.M0/sp.Msun:.1e} Msun")
        print(f"ma = {ma/sp.Msun:.1e} Msun")
        print(f"maximim Relative Errors")
        print(f"- default (%): {np.max(np.abs((_m_default-_m)/_m))*100:.2f}")
        print(f"- 0th (%): {np.max(np.abs((_m_pert0-_m)/_m))*100:.2f}")
        print(f"- 1st (%): {np.max(np.abs((_m_pert1-_m)/_m))*100:.2f}")
        print(f"- 2nd (%): {np.max(np.abs((_m_pert2-_m)/_m))*100:.2f}")
        print(f"- 2nd (Shanks) (%): {np.max(np.abs((_m_pert2_shanks-_m)/_m))*100:.2f}")
        print(f"- 3rd (%): {np.max(np.abs((_m_pert3-_m)/_m))*100:.2f}")
    plt.suptitle(f"ma = {ma/sp.Msun:.1e}, za = {za}, z = {z}")
    plt.tight_layout()
    plt.show()
# Out:
# Integration method: cumulative_trapezoid
# ...
# M0 = 1.0e+08 Msun
# ma = 1.0e-06 Msun
# maximim Relative Errors
# - default (%): 25.62
# - 0th (%): 88.74
# - 1st (%): 98.91
# - 2nd (%): 16.61
# - 2nd (Shanks) (%): 2.06
# - 3rd (%): 5.00
# ...
# M0 = 1.0e+10 Msun
# ma = 1.0e-06 Msun
# maximim Relative Errors
# - default (%): 24.79
# - 0th (%): 89.20
# - 1st (%): 99.75
# - 2nd (%): 16.08
# - 2nd (Shanks) (%): 2.37
# - 3rd (%): 4.57
# ...
# M0 = 1.0e+12 Msun
# ma = 1.0e-06 Msun
# maximim Relative Errors
# - default (%): 25.71
# - 0th (%): 89.00
# - 1st (%): 92.77
# - 2nd (%): 14.35
# - 2nd (Shanks) (%): 2.45
# - 3rd (%): 3.69
# ...
# M0 = 1.0e+14 Msun
# ma = 1.0e-06 Msun
# maximim Relative Errors
# - default (%): 29.18
# - 0th (%): 88.35
# - 1st (%): 80.04
# - 2nd (%): 11.83
# - 2nd (Shanks) (%): 2.20
# - 3rd (%): 2.63
# ...
# M0 = 1.0e+08 Msun
# ma = 1.0e-02 Msun
# maximim Relative Errors
# - default (%): 0.04
# - 0th (%): 82.53
# - 1st (%): 52.66
# - 2nd (%): 8.93
# - 2nd (Shanks) (%): 0.59
# - 3rd (%): 2.01
# ...

# %%
import tqdm
# plot subhalo_mass_stripped
sp = MySubhaloProperties(M0=1.e12)
# sp.M0 = 1.e12*sp.Msun
# chech calculation time
for _ma in [1.e-6, 1.e-2, 1.e2, 1.e6]:
    print("="*10)
    # fig, axs = plt.subplots(2,2,figsize=(10,10))
    # axs = axs.flatten()
    ma = _ma*sp.Msun
    za = 10.
    z = 0.
    print(f"ma = {ma/sp.Msun:.1e}, za = {za}, z = {z}")
    for i,log10_M0 in enumerate([8,10,12,14]): 
        print("-"*10) 
        print(f"M0 = {10**log10_M0:.1e} Msun")
        sp.M0 = 10**log10_M0*sp.Msun
        print("exact:",end="\t")
        # %timeit _z,_m = sp.subhalo_mass_stripped(ma,za,z)
        # # axs[i].plot(_z,_m/sp.Msun,label=f'exact',color='black') 
        # print("pert0:",end="\t")
        # %timeit _z,_m = sp.subhalo_mass_stripped_pert0(ma,za,z)
        # # axs[i].plot(_z,_m/sp.Msun,label=f'0th',linestyle='--')
        # print("pert1:",end="\t")
        # %timeit _z,_m = sp.subhalo_mass_stripped_pert1(ma,za,z)
        # # axs[i].plot(_z,_m/sp.Msun,label=f'1st',linestyle='--')
        # print("pert2:",end="\t")
        # %timeit _z,_m = sp.subhalo_mass_stripped_pert2(ma,za,z)
        # # axs[i].plot(_z,_m/sp.Msun,label=f'2nd',linestyle='--')
        print("0th:",end="\t")
        # %timeit _z,_m = sp.subhalo_mass_stripped(ma,za,z, method="pert0")
        print("1st:",end="\t")
        # %timeit _z,_m = sp.subhalo_mass_stripped(ma,za,z, method="pert1")
        print("2nd:",end="\t")
        # %timeit _z,_m = sp.subhalo_mass_stripped(ma,za,z, method="pert2")
        print("2nd (Shanks):",end="\t")
        # %timeit _z,_m = sp.subhalo_mass_stripped(ma,za,z, method="pert2_shanks")
        print("3rd:",end="\t")
        # %timeit _z,_m = sp.subhalo_mass_stripped(ma,za,z, method="pert3")
    #     axs[i].set_xlabel('z')
    #     axs[i].set_ylabel('m')
    #     axs[i].set_yscale('log')
    #     axs[i].legend()
    #     axs[i].set_title(f"M0 = {sp.M0/sp.Msun:.1e} Msun")
    # plt.suptitle(f"ma = {ma/sp.Msun:.1e}, za = {za}, z = {z}")
    # plt.show()
# Out:
# Integration method: cumulative_trapezoid
# ...
# ma = 1.0e-06, za = 10.0, z = 0.0
# ----------
# M0 = 1.0e+08 Msun
# exact:	7.21 ms ± 10.5 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 0th:	16.2 μs ± 123 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 1st:	31 μs ± 29.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 2nd:	52.1 μs ± 54.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 2nd (Shanks):	75.8 μs ± 96.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 3rd:	80.8 μs ± 121 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# ----------
# M0 = 1.0e+10 Msun
# exact:	7.84 ms ± 8.19 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 0th:	16.1 μs ± 21.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 1st:	31 μs ± 168 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 2nd:	51.8 μs ± 79 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# ...

# %% [markdown]
# ## Implementation with Sympy

# %%
# %pip install sympy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 38.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 35.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# use sympy to derive perturbation terms automatically
# Equation:
# \sum_{n=0}^{\infty} \frac{d\epsilon_n(z)}{dz} = \Phi(z) \exp\left( \zeta(z) \sum_{n=0}^{\infty} \epsilon'_n(z) \right)
import sympy
# from sympy.abc import i 
# define sequence e[i]
z = sympy.symbols('z')
ln_ma = sympy.symbols('\ln{m_a}')
ln_Mvir = sympy.Function('\ln{M_{vir}}')(z)
ep = sympy.symbols('\epsilon^{\prime}_0:10')
# ep = sympy.Function('\epsilon^{\prime}_0:10')(z)
e_func = []
for i in range(10):
    e_func.append(sympy.Function(f'\epsilon_{i}')(z))
    # display(e_func[i])
e = sympy.symbols('\epsilon_0:10')
zeta = sympy.symbols('\zeta')
zeta_func = sympy.Function('\zeta')(z)
# define Phi(z)
Phi = sympy.Function('Phi')(z)
# define dedz
n_max = 5
series = sympy.series(Phi * sympy.exp(zeta*sum( [ep[i]*zeta**i for i in range(10)] )),zeta,0,n_max)
dedz = []
e_formula = []
eq_i = []
for i in range(n_max):
    coeff = series.coeff(zeta,i)
    # display(coeff)
    for j in range(10):
        coeff = coeff.subs(ep[j],e_func[j]/zeta**j)
        coeff = coeff.subs(zeta,zeta_func)
    _dedz = zeta_func**i * coeff
    _dedz = _dedz.expand()
    # if i == 0:
    e_func_0 = sympy.Function('\ln(m_0/M_{vir})')(z)
    _dedz = _dedz.subs(e_func[0],e_func_0)
    dedz.append(_dedz)
    _e_formula = sympy.integrate(_dedz,z)
    _e_formula = _e_formula.cancel()  # cancel out common factors for each term
    e_formula.append(_e_formula)
    display(sympy.Eq(e_func[i],_e_formula))
# display(series)

print(f"where {sympy.Function('m_0')(z)} means the zeroth order solution of m")
# Out:
# Eq(\epsilon_0(z), Integral(Phi(z), z))
# Eq(\epsilon_1(z), Integral(Phi(z)*\ln(m_0/M_{vir})(z)*\zeta(z), z))
# Eq(\epsilon_2(z), Integral(Phi(z)*\epsilon_1(z)*\zeta(z), z) + Integral(Phi(z)*\ln(m_0/M_{vir})(z)**2*\zeta(z)**2, z)/2)
# Eq(\epsilon_3(z), Integral(Phi(z)*\epsilon_2(z)*\zeta(z), z) + Integral(Phi(z)*\ln(m_0/M_{vir})(z)**3*\zeta(z)**3, z)/6 + Integral(Phi(z)*\epsilon_1(z)*\ln(m_0/M_{vir})(z)*\zeta(z)**2, z))
# Eq(\epsilon_4(z), Integral(Phi(z)*\epsilon_1(z)**2*\zeta(z)**2, z)/2 + Integral(Phi(z)*\epsilon_3(z)*\zeta(z), z) + Integral(Phi(z)*\ln(m_0/M_{vir})(z)**4*\zeta(z)**4, z)/24 + Integral(Phi(z)*\epsilon_1(z)*\ln(m_0/M_{vir})(z)**2*\zeta(z)**3, z)/2 + Integral(Phi(z)*\epsilon_2(z)*\ln(m_0/M_{vir})(z)*\zeta(z)**2, z))
# where m_0(z) means the zeroth order solution of m

# %%
# use sympy to derive perturbation terms automatically
# Equation:
# \sum_{n=0}^{\infty} \frac{d\epsilon_n(z)}{dz} = \Phi(z) \exp\left( \zeta(z) \sum_{n=0}^{\infty} \epsilon'_n(z) \right)
import sympy
# from sympy.abc import i 
# define sequence e[i]
z = sympy.symbols('z')
ln_ma = sympy.symbols('\ln{m_a}')
ln_Mvir = sympy.Function('\ln{M_{vir}}')(z)
ep = sympy.symbols('\epsilon^{\prime}_0:10')
# ep = sympy.Function('\epsilon^{\prime}_0:10')(z)
e_func = []
for i in range(10):
    e_func.append(sympy.Function(f'\epsilon_{i}')(z))
    # display(e_func[i])
e = sympy.symbols('\epsilon_0:10')
zeta = sympy.symbols('\zeta')
zeta_func = sympy.Function('\zeta')(z)
# define Phi(z)
Phi = sympy.Function('Phi')(z)
# define dedz
n_max = 5
series = sympy.series(Phi * sympy.exp(zeta*sum( [ep[i]*zeta**i for i in range(10)] )),zeta,0,n_max)
dedz = []
e_formula = []
eq_i = []
for i in range(n_max):
    coeff = series.coeff(zeta,i)
    # display(coeff)
    for j in range(10):
        coeff = coeff.subs(ep[j],e_func[j]/zeta**j)
        coeff = coeff.subs(zeta,zeta_func)
    _dedz = zeta_func**i * coeff
    _dedz = _dedz.expand()
    # if i == 0:
    e_func_0 = e_func[0] + ln_ma - ln_Mvir
    _dedz = _dedz.subs(e_func[0],e_func_0)
    _dedz = _dedz.collect(ln_ma)
    dedz.append(_dedz)
    _e_formula = sympy.integrate(_dedz,z)
    _e_formula = _e_formula.cancel()  # cancel out common factors for each term
    e_formula.append(_e_formula)
    display(sympy.Eq(e_func[i],_e_formula))
# display(series)
# Out:
# Eq(\epsilon_0(z), Integral(Phi(z), z))
# Eq(\epsilon_1(z), Integral(\ln{m_a}*Phi(z)*\zeta(z), z) + Integral(Phi(z)*\epsilon_0(z)*\zeta(z), z) + Integral(-Phi(z)*\ln{M_{vir}}(z)*\zeta(z), z))
# Eq(\epsilon_2(z), \ln{m_a}**2*Integral(Phi(z)*\zeta(z)**2, z)/2 + \ln{m_a}*Integral(Phi(z)*\epsilon_0(z)*\zeta(z)**2, z) - \ln{m_a}*Integral(Phi(z)*\ln{M_{vir}}(z)*\zeta(z)**2, z) + Integral(Phi(z)*\epsilon_0(z)**2*\zeta(z)**2, z)/2 + Integral(Phi(z)*\epsilon_1(z)*\zeta(z), z) + Integral(Phi(z)*\ln{M_{vir}}(z)**2*\zeta(z)**2, z)/2 - Integral(Phi(z)*\epsilon_0(z)*\ln{M_{vir}}(z)*\zeta(z)**2, z))
# ...

# %%
# use sympy to derive perturbation terms automatically
# Equation:
# \sum_{n=0}^{\infty} \frac{d\epsilon_n(z)}{dz} = \Phi(z) \exp\left( \zeta(z) \sum_{n=0}^{\infty} \epsilon'_n(z) \right)
import sympy
# from sympy.abc import i 
# define sequence e[i]
z = sympy.symbols('z')
ln_ma = sympy.symbols('\ln{m_a}')
ln_Mvir = sympy.Function('\ln{M_{vir}}')(z)
ep = sympy.symbols('\epsilon^{\prime}_0:10')
# ep = sympy.Function('\epsilon^{\prime}_0:10')(z)
e_func = []
for i in range(10):
    e_func.append(sympy.Function(f'\epsilon_{i}')(z))
    # display(e_func[i])
e_func_sub = {}
e_formula_sub = {}
for i in range(10):
    for j in range(i+1):
        _e_func_sub = sympy.Function(f'\epsilon_{i}{j}')(z)
        e_func_sub[(i,j)] = _e_func_sub
# display(e_func_sub)

e = sympy.symbols('\epsilon_0:10')
zeta = sympy.symbols('\zeta')
zeta_func = sympy.Function('\zeta')(z)
# define Phi(z)
Phi = sympy.Function('Phi')(z)
# define dedz
n_max = 4
series = sympy.series(Phi * sympy.exp(zeta*sum( [ep[i]*zeta**i for i in range(10)] )),zeta,0,n_max)
dedz = []
e_formula = []
eq_i = []
for i in range(n_max):
    coeff = series.coeff(zeta,i)
    # display(coeff)
    for j in range(10):
        coeff = coeff.subs(ep[j],e_func[j]/zeta**j)
        coeff = coeff.subs(zeta,zeta_func)
    _dedz = zeta_func**i * coeff
    _dedz = _dedz.expand()
    # if i == 0:
    e_func_0 = e_func[0] + ln_ma - ln_Mvir
    _dedz = _dedz.subs(e_func[0],e_func_0)
    _dedz = _dedz.collect(ln_ma)
    # for _e_func,_e_formula in zip(e_func,e_formula):
    #     _dedz = _dedz.subs(_e_func,_e_formula)
    # for j, _e_func in enumerate(e_func):
    #     _dedz = _dedz.subs(_e_func,sum([e_func_sub[(i,k)]*ln_ma**k for k in range(i+1)]))
    for j in range(i):
        _dedz = _dedz.subs(e_func[j],sum([e_func_sub[(j,k)]*ln_ma**k for k in range(j+1)]))
    dedz.append(_dedz)
    _e_formula = sympy.integrate(_dedz,z)
    _e_formula = _e_formula.cancel()  # cancel out common factors for each term
    if i == 1:
        _e_formula = _e_formula.simplify()
    e_formula.append(_e_formula)
    display(sympy.Eq(e_func[i],_e_formula))
    for j in range(i+1):
        _coeff = _e_formula.coeff(ln_ma,j)
        e_formula_sub[(i,j)] = _coeff
        # print((i,j))
        display(sympy.Eq(e_func_sub[(i,j)],_coeff))
    display(sympy.Eq(e_func[i],sum([e_func_sub[(i,j)]*ln_ma**j for j in range(i+1)])))
# display(series)
# Out:
# Eq(\epsilon_0(z), Integral(Phi(z), z))
# Eq(\epsilon_00(z), Integral(Phi(z), z))
# Eq(\epsilon_0(z), \epsilon_00(z))
# Eq(\epsilon_1(z), \ln{m_a}*Integral(Phi(z)*\zeta(z), z) + Integral(Phi(z)*\epsilon_00(z)*\zeta(z), z) - Integral(Phi(z)*\ln{M_{vir}}(z)*\zeta(z), z))
# Eq(\epsilon_10(z), Integral(Phi(z)*\epsilon_00(z)*\zeta(z), z) - Integral(Phi(z)*\ln{M_{vir}}(z)*\zeta(z), z))
# Eq(\epsilon_11(z), Integral(Phi(z)*\zeta(z), z))
# Eq(\epsilon_1(z), \ln{m_a}*\epsilon_11(z) + \epsilon_10(z))
# Eq(\epsilon_2(z), \ln{m_a}**2*Integral(Phi(z)*\zeta(z)**2, z)/2 + \ln{m_a}*Integral(Phi(z)*\epsilon_00(z)*\zeta(z)**2, z) + \ln{m_a}*Integral(Phi(z)*\epsilon_11(z)*\zeta(z), z) - \ln{m_a}*Integral(Phi(z)*\ln{M_{vir}}(z)*\zeta(z)**2, z) + Integral(Phi(z)*\epsilon_00(z)**2*\zeta(z)**2, z)/2 + Integral(Phi(z)*\epsilon_10(z)*\zeta(z), z) + Integral(Phi(z)*\ln{M_{vir}}(z)**2*\zeta(z)**2, z)/2 - Integral(Phi(z)*\epsilon_00(z)*\ln{M_{vir}}(z)*\zeta(z)**2, z))
# ...

# %%
e_formula[1]
# Out:
# Integral(\ln{m_a}*Phi(z)*\zeta(z), z) + Integral(-Phi(z)*\ln{M_{vir}}(z)*\zeta(z), z) + Integral(Phi(z)*\zeta(z)*Integral(Phi(z), z), z)

# %%
e_formula[1].simplify()
# Out:
# \ln{m_a}*Integral(Phi(z)*\zeta(z), z) - Integral(Phi(z)*\ln{M_{vir}}(z)*\zeta(z), z) + Integral(Phi(z)*\zeta(z)*Integral(Phi(z), z), z)

# %%
e_formula[2]
# Out:
# \ln{m_a}**2*Integral(Phi(z)*\zeta(z)**2, z)/2 - \ln{m_a}*Integral(Phi(z)*\ln{M_{vir}}(z)*\zeta(z)**2, z) + \ln{m_a}*Integral(Phi(z)*\zeta(z)*Integral(Phi(z)*\zeta(z), z), z) + \ln{m_a}*Integral(Phi(z)*\zeta(z)**2*Integral(Phi(z), z), z) + Integral(Phi(z)*\ln{M_{vir}}(z)**2*\zeta(z)**2, z)/2 - Integral(Phi(z)*\zeta(z)*Integral(Phi(z)*\ln{M_{vir}}(z)*\zeta(z), z), z) + Integral(Phi(z)*\zeta(z)*Integral(Phi(z)*\zeta(z)*Integral(Phi(z), z), z), z) + Integral(Phi(z)*\zeta(z)**2*Integral(Phi(z), z)**2, z)/2 - Integral(Phi(z)*\ln{M_{vir}}(z)*\zeta(z)**2*Integral(Phi(z), z), z)

# %%
e_formula[2].simplify()
# Out:
# \ln{m_a}**2*Integral(Phi(z)*\zeta(z)**2, z)/2 - \ln{m_a}*Integral(Phi(z)*\ln{M_{vir}}(z)*\zeta(z)**2, z) + \ln{m_a}*Integral(Phi(z)*\zeta(z)*Integral(Phi(z)*\zeta(z), z), z) + \ln{m_a}*Integral(Phi(z)*\zeta(z)**2*Integral(Phi(z), z), z) + Integral(Phi(z)*\ln{M_{vir}}(z)**2*\zeta(z)**2, z)/2 - Integral(Phi(z)*\zeta(z)*Integral(Phi(z)*\ln{M_{vir}}(z)*\zeta(z), z), z) + Integral(Phi(z)*\zeta(z)*Integral(Phi(z)*\zeta(z)*Integral(Phi(z), z), z), z) + Integral(Phi(z)*\zeta(z)**2*Integral(Phi(z), z)**2, z)/2 - Integral(Phi(z)*\ln{M_{vir}}(z)*\zeta(z)**2*Integral(Phi(z), z), z)
